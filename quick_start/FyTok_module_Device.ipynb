# %% [markdown]
# # 装置中的子系统
#
# 用以记录和描述装置独立的子系统状态的 IDS 包括：
#
# - 装置: wall, pf_active...
# - 诊断 : magnetics, ECE, Langmuir Probes , Polarimeter...
# - 辅助系统: LH Antennas, ECLauhchers,IC Antennas, NBI, Pellets...
#
# 数据来源包括：
#
# - 装置静态几何信息；
# - 实际控制信号或者设计控制方案；
# - 实验诊断数据；
#
# 对于这类 IDS ，{{FyTok}} 通过 {{SpDM}} 数据集成工具将不同来源的数据汇总、映射为符合 IMAS Ontology 的形式。对于 EAST 目前完成数据映射的子系统有：wall, pf_active, magnetics.
#
# ```{note}
# 在后续示例中，分别以 `wall, pf_active, magnetics` 子系统作为示例，展示如何使用 {{FyTok}} 读取、处理、分析、可视化装置子系统数据。其中数据源包括：本地文件、数据库、远程服务器等。关于数据源的配置请参考{{SpDM}}的相关文档。
# ```

# %%
import os 
os .environ["FY_VERBOSE"]="debug"

from spdm.view import sp_view

# %% [markdown]
# ## wall

# %% [markdown]
# `wall` 提供对托卡马克装置第一壁的描述（继承自 IMAS Ontology 的定义）
#
# ```{eval-rst}
#
# .. autoclass:: fytok.modules.Wall.Wall
#     :members: description_2d
#     :undoc-members: time_slice
#     :member-order: bysource
#     :show-inheritance: True
#
# ```

# %% [markdown]
# ### 创建 `Wall` 实例

# %%
from fytok.modules.wall import Wall

wall = Wall("east://#wall")
# Out:
# 2024-06-01 09:58:43,317 [   fytok]     INFO: Failed to import IMAS wrapper. Using dummy ontology as fallback.
# 2024-06-01 09:58:44,050 [   fytok]     INFO:
# ###################################################################################################
#
#     ______      _____     _
#    / ____/_  __|_   _|__ | | __
#   / /_  / / / /  | |/ _ \| |/ /
#  / __/ / /_/ /   | | (_) |   <
# /_/    \__, /    |_|\___/|_|\_\
#       /____/
#
#  Copyright (c) 2021-present Zhi YU @ Institute of Plasma Physics Chinese Academy of Sciences
#
#  version = 0.4.1  (spdm=beta extension=0.2.3.dev0+g2cc21ff.d20240223)
#
#  Run by salmon at 2024-06-01T09:58:43.316736.
#  Job ID: fytok_salmon_surface_6662
#
# ###################################################################################################

# %% [markdown]
# 由于`Wall`的描述来自装置信息，采用 URI `east://#wall`指定数据源。其中，`east://` 指定了装置 identificer ， {{FyTok}} 会根据其匹配合适的装置描述文件。`#wall` 意为从树中裁剪 `wall` 所对应的一支。由于不涉及数据库或其他动态数据源，省略了 URI 其他部分。
#
# 其中，关于 `limiter` 几何信息（ `wall.description_2d[0].limiter.unit[0].outline` ） 以`r`，`z`坐标数组的形式描述

# %% [markdown]
# ### 可视化效果

# %%
fig = sp_view.display(wall)

# %% [markdown]
# ## pf_active

# %% [markdown]
# `pf_active` 提供对托卡马克装置极向场线圈的描述（继承自 IMAS Ontology 的定义）
#
# ```{eval-rst}
#
# .. autoclass::fytok.ontology.imas_lastest.pf_active._T_pf_coils
#     :members: *
#     :member-order: bysource
#     :show-inheritance: True
# .. autoclass:: fytok.modules.PFActive.PFActive
#     :members: coil
#     :undoc-members: time_slice
#     :member-order: bysource
#     :show-inheritance: True
#
# ```

# %% [markdown]
# ### 创建 `PFActive` 实例
#
# 以本地 MDSplus 数据创建 `PFActive` 实例：

# %%
from fytok.modules.pf_active import PFActive

pf_active = PFActive(f"east+mdsplus://./mdsplus/~t/?shot=70754#pf_active")

# %% [markdown]
# ### 可视化
#
# - 2D ：pf 线圈截面

# %%
fig=sp_view.display(pf_active)
# Out:
# 2024-06-01 09:58:45,377 [   fytok]    ERROR: /home/salmon/workspace/fytok/SpDM/python/spdm/view/view_matplotlib.py:166:_draw: ignore unsupported geometry PFActive <PFActive name='PFActive' />!
# Traceback (most recent call last):
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py", line 158, in query
#     res = tree.tdiExecute(tdi).data()
#           ^^^^^^^^^^^^^^^^^^^^
#   File "/fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/tree.py", line 1145, in tdiExecute
#     return _dat.TdiExecute(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/mdsdata.py", line 93, in TdiExecute
#     return _cmp.EXECUTE(expression, *_unwrap(args))._setTree(**kwargs).evaluate()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/compound.py", line 329, in __init__
#     super(Function,self).__init__(*args)
#   File "/fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/compound.py", line 57, in __init__
#     self.setDescs(args)
#   File "/fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/compound.py", line 127, in setDescs
#     self._descs = [_dat.Data(arg) for arg in args]
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/compound.py", line 127, in <listcomp>
#     self._descs = [_dat.Data(arg) for arg in args]
#                    ^^^^^^^^^^^^^^
#   File "/fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/mdsscalar.py", line 422, in __init__
#     if not isinstance(self._value, _N.str):
#                                    ^^^^^^
#   File "/fuyun/software/SciPy-bundle/2023.07-gfbf-2023a/lib/python3.11/site-packages/numpy/__init__.py", line 313, in __getattr__
#     raise AttributeError(__former_attrs__[attr])
# AttributeError: module 'numpy' has no attribute 'str'.
# `np.str` was a deprecated alias for the builtin `str`. To avoid this error in existing code, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/view/view_matplotlib.py", line 161, in _draw
#     geo = geo.__geometry__(view_point=view_point, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/python/fytok/modules/pf_active.py", line 14, in __geometry__
#     for coil in self.coil:
#                 ^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/sp_property.py", line 143, in __getattr__
#     value = _entry.get(default_value=_not_found_)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 123, in get
#     return entry.find(Path.tags.find, *args, default_value=default_value, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 748, in find
#     return self._op_find(request, default_value=default_value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 789, in _op_find
#     res = [self._op_find(req, *args, **kwargs) for req in request]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 789, in <listcomp>
#     res = [self._op_find(req, *args, **kwargs) for req in request]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 795, in _op_find
#     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 795, in <dictcomp>
#     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 795, in _op_find
#     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 795, in <dictcomp>
#     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 803, in _op_find
#     res = entry.find(request.get("_text"), *args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py", line 250, in find
#     return self._data.query(request, *args, prefix=self._path, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py", line 167, in query
#     raise RuntimeError(f'mds.mdsExceptions! tree_name={tree_name} shot={self._shot} tdi="{tdi}"') from error
# RuntimeError: mds.mdsExceptions! tree_name=pcs_east shot=70754 tdi="DATA(\pcpf1 )"
# /fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/mdsscalar.py:422: FutureWarning: In the future `np.str` will be defined as the corresponding NumPy scalar.
#   if not isinstance(self._value, _N.str):

# %% [markdown]
# - 1D ：pf 线圈电流随时间变化

# %%
fig = sp_view.plot([(coil.current, {"label": False}) for coil in pf_active.coil], y_label=f"PF [A]", x_label="time[s]",title="PF Coil current")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py:158, in MDSplusTree.query(self, request, prefix, **kwargs)
#     157 try:
# --> 158     res = tree.tdiExecute(tdi).data()
#     159 except mds.mdsExceptions.TdiException as error:
#     160     # raise RuntimeError(f"MDSplus TDI error [{tdi}]! {error}")
#
# File /fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/tree.py:1145, in Tree.tdiExecute(self, *args, **kwargs)
#    1144 kwargs['tree'] = self
# -> 1145 return _dat.TdiExecute(*args, **kwargs)
#
# File /fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/mdsdata.py:93, in TdiExecute(expression, *args, **kwargs)
#      92 """Compile and evaluate a TDI expression. Format: TdiExecute('expression-string')"""
# ---> 93 return _cmp.EXECUTE(expression, *_unwrap(args))._setTree(**kwargs).evaluate()
#
# File /fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/compound.py:329, in Function.__init__(self, *args)
#     328         raise TypeError("Requires %d to %d input arguments for %s but %d given"%(self.min_args,self.max_args,self.__class__.__name__,len(args)))
# --> 329 super(Function,self).__init__(*args)
#
# File /fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/compound.py:57, in Compound.__init__(self, *args, **kwargs)
#      56 self._argOffset=len(self.fields)
# ---> 57 self.setDescs(args)
#      58 for k,v in kwargs:
#
# File /fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/compound.py:127, in Compound.setDescs(self, args)
#     124 """Set descriptors
#     125 @type args: tuple
#     126 """
# --> 127 self._descs = [_dat.Data(arg) for arg in args]
#     128 self._setTree(*args)
#
# File /fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/compound.py:127, in <listcomp>(.0)
#     124 """Set descriptors
#     125 @type args: tuple
#     126 """
# --> 127 self._descs = [_dat.Data(arg) for arg in args]
#     128 self._setTree(*args)
#
# File /fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/mdsscalar.py:422, in String.__init__(self, value)
#     421 super(String, self).__init__(value)
# --> 422 if not isinstance(self._value, _N.str):
#     423     self._value = _ver.npstr(_ver.tostr(self._value))
#
# File /fuyun/software/SciPy-bundle/2023.07-gfbf-2023a/lib/python3.11/site-packages/numpy/__init__.py:313, in __getattr__(attr)
#     312 if attr in __former_attrs__:
# --> 313     raise AttributeError(__former_attrs__[attr])
#     315 if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'str'.
# `np.str` was a deprecated alias for the builtin `str`. To avoid this error in existing code, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fig = sp_view.plot([(coil.current, {"label": False}) for coil in pf_active.coil], y_label=f"PF [A]", x_label="time[s]",title="PF Coil current")
#
# File ~/workspace/fytok/SpDM/python/spdm/core/sp_property.py:143, in PropertyTree.__getattr__(self, key, *args, **kwargs)
#     141 value = Path._do_find(self._cache, [key], *args, **kwargs)
#     142 if value is _not_found_ and _entry is not None:
# --> 143     value = _entry.get(default_value=_not_found_)
#     144     _entry = None
#     145 if isinstance(value, dict):
#
# File ~/workspace/fytok/SpDM/python/spdm/core/entry.py:123, in Entry.get(self, query, default_value, **kwargs)
#     120     entry = self.child(query)
#     121     args = ()
# --> 123 return entry.find(Path.tags.find, *args, default_value=default_value, **kwargs)
#
# File ~/workspace/fytok/SpDM/python/spdm/core/entry.py:748, in EntryProxy.find(self, default_value, *args, **kwargs)
#     745 def find(self, *args, default_value=_not_found_, **kwargs) -> typing.Any:
#     746     request = self._mapper.child(self._path).find(*args, default_value=_not_found_, lazy=False, **kwargs)
# --> 748     return self._op_find(request, default_value=default_value)
#
# File ~/workspace/fytok/SpDM/python/spdm/core/entry.py:789, in EntryProxy._op_find(self, request, *args, **kwargs)
#     786     res = EntryProxy(request, self._entry_list)
#     788 elif isinstance(request, list):
# --> 789     res = [self._op_find(req, *args, **kwargs) for req in request]
#     791 elif not isinstance(request, dict):
#     792     res = request
#
# File ~/workspace/fytok/SpDM/python/spdm/core/entry.py:789, in <listcomp>(.0)
#     786     res = EntryProxy(request, self._entry_list)
#     788 elif isinstance(request, list):
# --> 789     res = [self._op_find(req, *args, **kwargs) for req in request]
#     791 elif not isinstance(request, dict):
#     792     res = request
#
# File ~/workspace/fytok/SpDM/python/spdm/core/entry.py:795, in EntryProxy._op_find(self, request, *args, **kwargs)
#     792     res = request
#     794 elif "@spdb" not in request:
# --> 795     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#     797 else:
#     798     entry = self._get_entry_by_name(request.get("@spdb", None))
#
# File ~/workspace/fytok/SpDM/python/spdm/core/entry.py:795, in <dictcomp>(.0)
#     792     res = request
#     794 elif "@spdb" not in request:
# --> 795     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#     797 else:
#     798     entry = self._get_entry_by_name(request.get("@spdb", None))
#
# File ~/workspace/fytok/SpDM/python/spdm/core/entry.py:795, in EntryProxy._op_find(self, request, *args, **kwargs)
#     792     res = request
#     794 elif "@spdb" not in request:
# --> 795     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#     797 else:
#     798     entry = self._get_entry_by_name(request.get("@spdb", None))
#
# File ~/workspace/fytok/SpDM/python/spdm/core/entry.py:795, in <dictcomp>(.0)
#     792     res = request
#     794 elif "@spdb" not in request:
# --> 795     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#     797 else:
#     798     entry = self._get_entry_by_name(request.get("@spdb", None))
#
# File ~/workspace/fytok/SpDM/python/spdm/core/entry.py:803, in EntryProxy._op_find(self, request, *args, **kwargs)
#     800     if not isinstance(entry, Entry):
#     801         raise RuntimeError(f"Can not find entry for {request}")
# --> 803     res = entry.find(request.get("_text"), *args, **kwargs)
#     805 return res
#
# File ~/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py:250, in MDSplusEntry.find(self, request, *args, **kwargs)
#     249 def find(self, request, *args, **kwargs):
# --> 250     return self._data.query(request, *args, prefix=self._path, **kwargs)
#
# File ~/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py:167, in MDSplusTree.query(self, request, prefix, **kwargs)
#     164     logger.warning(f'MDS No data! tree_name={tree_name} shot={self._shot} tdi="{tdi}" \n {error}')
#     166 except Exception as error:
# --> 167     raise RuntimeError(f'mds.mdsExceptions! tree_name={tree_name} shot={self._shot} tdi="{tdi}"') from error
#     168     # raise error
#     170 if not isinstance(res, np.ndarray):
#
# RuntimeError: mds.mdsExceptions! tree_name=pcs_east shot=70754 tdi="DATA(\pcpf1 )"

# %% [markdown]
# ## magnetics

# %% [markdown]
# `magnetics` 提供对托卡马克磁探针的描述（继承自 IMAS Ontology 的定义）
#
# ```{eval-rst}
#
#
# .. autoclass:: fytok.modules.Magnetics.Magnetics
#     :members: b_field_pol_probe, flux_loop
#     :member-order: bysource
#     :show-inheritance: True
#
# ```

# %% [markdown]
# ### 创建 `Magnetics` 实例
#
# 以远程 MDSplus 数据库创建 `Magnetics` 实例：

# %%
from fytok.modules.magnetics import Magnetics

magnetics = Magnetics(f"east+mdsplus://202.127.204.12?shot=70754#magnetics")

# %% [markdown]
# ### 可视化
#
# - 2D ：磁探针空间分布

# %%
fig = sp_view.display(magnetics)
# Out:
# 2024-06-01 09:59:17,647 [   fytok]    ERROR: /home/salmon/workspace/fytok/SpDM/python/spdm/view/view_matplotlib.py:166:_draw: ignore unsupported geometry Magnetics <Magnetics name='Magnetics' />!
# Traceback (most recent call last):
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py", line 117, in get_tree
#     tree = mds.Tree(tree_name, shot, mode=mode, path=tree_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/tree.py", line 559, in __init__
#     self.open(mode)
#   File "/fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/tree.py", line 531, in open
#     _exc.checkStatus(status)
#   File "/fuyun/software/MDSplus/7.132.0-foss-2023a/lib/python3.11/site-packages/MDSplus/mdsExceptions.py", line 94, in checkStatus
#     raise exception
# MDSplus.mdsExceptions.TreeFOPENR: %TREE-E-FOPENR, Error opening file read-only.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/view/view_matplotlib.py", line 161, in _draw
#     geo = geo.__geometry__(view_point=view_point, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/python/fytok/modules/magnetics.py", line 19, in __geometry__
#     if self.flux_loop is not _not_found_:
#        ^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/sp_property.py", line 143, in __getattr__
#     value = _entry.get(default_value=_not_found_)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 123, in get
#     return entry.find(Path.tags.find, *args, default_value=default_value, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 748, in find
#     return self._op_find(request, default_value=default_value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 789, in _op_find
#     res = [self._op_find(req, *args, **kwargs) for req in request]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 789, in <listcomp>
#     res = [self._op_find(req, *args, **kwargs) for req in request]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 795, in _op_find
#     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 795, in <dictcomp>
#     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 795, in _op_find
#     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 795, in <dictcomp>
#     res = {k: self._op_find(req, *args, **kwargs) for k, req in request.items()}
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/core/entry.py", line 803, in _op_find
#     res = entry.find(request.get("_text"), *args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py", line 250, in find
#     return self._data.query(request, *args, prefix=self._path, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py", line 156, in query
#     tree = self.get_tree(tree_name, tree_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/salmon/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py", line 119, in get_tree
#     raise FileNotFoundError(
# FileNotFoundError: Can not open mdsplus tree! tree_name=pcs_east shot=70754 tree_path=202.127.204.12:: mode=ReadOnly
#  %TREE-E-FOPENR, Error opening file read-only.
# Error in connect: timeout
# send_bytes: Error sending data to remote server: Resource temporarily unavailable
# Error during login: send: Resource temporarily unavailable
# W, 1717207157.645:  remote_connect()              Host(conid=-1, links=?, unique='tcp://202.127.204.12:8000'), server='202.127.204.12': error
# Error connecting to host /202.127.204.12/ in io_open_one_remote

# %% [markdown]
# - 2D ：磁探针信号随时间变化

# %%
fig = sp_view.plot(
    ([(probe.flux, {"label": False}) for probe in magnetics.flux_loop], {"y_label": f"[Wb]"}),
    x_label="time[s]",
    title=" flux_loop",
)
