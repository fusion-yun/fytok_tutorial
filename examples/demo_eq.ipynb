# %%
from fytok.modules.Equilibrium import Equilibrium

# %%
equilibrium = Equilibrium({"code": {"name": "eq_demo"}}, "file+geqdsk://../tutorial/data/g070754.05000#equilibrium")
# Out:
# 2023-12-03 08:33:22,823 [   fytok]     INFO: Load module fytok.plugins.equilibrium.eq_demo
# 2023-12-03 08:33:22,827 [   fytok]     INFO: Load module spdm.plugins.data.plugin_geqdsk
# 2023-12-03 08:33:22,837 [   fytok]     INFO: Initialize module fytok.plugins.equilibrium.eq_demo [0.0.0-FyTok demo]

# %%
equilibrium.time_slice.current.profiles_2d.psi
# Out:
# 2023-12-03 08:33:22,853 [   fytok]     INFO: Load module spdm.mesh.mesh_rectangular
# 2023-12-03 08:33:22,858 [   fytok]     INFO: Load module spdm.view.view_matplotlib
# psi

# %%
equilibrium.code.name
# Out:
# 'eq_demo'

# %%
from fytok.Tokamak import Tokamak

# %%
tokamak = Tokamak(f"east+mdsplus://202.127.204.12", shot=70754)
# Out:
# 2023-12-03 08:33:23,176 [   fytok]     INFO: Load module spdm.plugins.data.plugin_xml

# %%
tokamak.magnetics.flux_loop[0].flux(1.0)
# Out:
# 2023-12-03 08:33:23,201 [   fytok]     INFO: Initialize module fytok.modulestags.not_found [0.0.0-fytok]
# 2023-12-03 08:33:23,236 [   fytok]     INFO: Load module spdm.plugins.data.plugin_mdsplus
# 2023-12-03 08:33:24,141 [   fytok]    DEBUG: /home/salmon/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py:118:get_tree: Open MDSplus Tree [pcs_east] shot=70754
# 3.3839204245802375

# %%
tokamak.tf.coil[0].current(1.0)
# Out:
# 2023-12-03 08:33:24,260 [   fytok]     INFO: Initialize module fytok.modulestags.not_found [0.0.0-fytok]
# 2023-12-03 08:33:25,349 [   fytok]    DEBUG: /home/salmon/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py:118:get_tree: Open MDSplus Tree [east] shot=70754
# -8006.28662109375
