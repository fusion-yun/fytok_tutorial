# %%
from fytok.Tokamak import Tokamak
from spdm.view import View as sp_view
# Out:
# 2023-11-06 15:27:03,504 [   fytok]     INFO:
# #######################################################################################################################
#     ______      _____     _
#    / ____/_  __|_   _|__ | | __
#   / /_  / / / /  | |/ _ \| |/ /
#  / __/ / /_/ /   | | (_) |   <
# /_/    \__, /    |_|\___/|_|\_\
#       /____/
#
#  Copyright (c) 2021-present Zhi YU (Institute of Plasma Physics Chinese Academy of Sciences)
#
#  url: https://gitee.com/openfusion/fytok_tutorial
#       https://github.com/fusion-yun/fytok_tutorial
#
#  ontology = imas/3, version = 0.2.2.dev45+g2d18fac.d20231106 ( extension=0.2.2.dev11+g706f667, imas_version=v3_38_1_dirty )
#
#  Run by salmon on Surface at 2023-11-06T15:27:03.504926
#
# #######################################################################################################################

# %%
tok_d3d = Tokamak(f"file+GEQdsk:///home/salmon/workspace/gacode/neo/tools/input/profile_data/g141459.03890",
              device="d3d")
fig2=sp_view.display(tok_d3d,title=tok_d3d.short_description,styles={"pf_active": False},)
# Out:
# 2023-11-06 15:27:03,599 [   fytok]     INFO: Load module spdm.plugins.data.plugin_xml
# 2023-11-06 15:27:03,605 [   fytok]     INFO: Load module spdm.plugins.data.plugin_geqdsk
# 2023-11-06 15:27:03,613 [   fytok]     INFO: Load module spdm.view.view_matplotlib
# 2023-11-06 15:27:04,302 [   fytok]     INFO: Load module fytok.plugins.equilibrium.eq_analyze

# %%
tok_east = Tokamak(f"east+mdsplus:///home/salmon/workspace/fytok_data/mdsplus/~t/?enable=efit_east",  shot=70754, )

tok_east.refresh(time=5.0)


fig3 = sp_view.display(tok_east, title=tok_east.short_description, styles={"interferometer": False})
# Out:
# 2023-11-06 15:27:05,176 [   fytok]     INFO: Load module spdm.plugins.data.plugin_mdsplus
# 2023-11-06 15:27:05,179 [   fytok]    DEBUG: /home/salmon/workspace/fytok/SpDM/python/spdm/plugins/data/plugin_mdsplus.py:118:get_tree: Open MDSplus Tree [efit_east] shot=70754
