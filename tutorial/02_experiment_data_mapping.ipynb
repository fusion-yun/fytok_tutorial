# %%
from fytok.Tokamak import Tokamak
from spdm.view import View as sp_view
# Out:
# 2023-10-09 18:12:53,917 [   fytok]     INFO:
# #######################################################################################################################
#
#     ______      _____     _
#    / ____/_  __|_   _|__ | | __
#   / /_  / / / /  | |/ _ \| |/ /
#  / __/ / /_/ /   | | (_) |   <
# /_/    \__, /    |_|\___/|_|\_\
#       /____/
# Copyright (c) 2021-present Zhi YU (Institute of Plasma Physics Chinese Academy of Sciences)
# URL         : https://gitee.com/openfusion/fytok_tutorial
#
# version = 0.0.0
# #######################################################################################################################
#
# 2023-10-09 18:12:53,940 [   fytok]     INFO: Mapping path [PosixPath('/home/salmon/workspace/fytok/python/fytok/_mapping')]
# 2023-10-09 18:12:54,168 [   fytok]     INFO: FyTok (0.2.0-164-g2d28512-dirty) is compatible with the IMAS data dictionary 3.38.1-dirty.

# %%
tok_d3d = Tokamak(f"file+GEQdsk:///home/salmon/workspace/gacode/neo/tools/input/profile_data/g141459.03890",
              device="d3d")
fig2=sp_view.display(tok_d3d,title=tok_d3d.short_description,styles={"pf_active": False},)
# Out:
# 2023-10-09 18:13:45,986 [    spdm]    DEBUG: /home/salmon/workspace/output/../fytok/python/spdm/plugins/data/plugin_geqdsk.py:437:__init__: Open File mode=Mode.read  URITuple(protocol='file+geqdsk', authority='', path='/home/salmon/workspace/gacode/neo/tools/input/profile_data/g141459.03890', query={'shot': '', 'run': '', 'uid': ''}, fragment='')
# 2023-10-09 18:13:46,028 [   fytok]     INFO: Load module Wall
# 2023-10-09 18:13:46,083 [   fytok]     INFO: Load module TF
# 2023-10-09 18:13:46,088 [   fytok]     INFO: Load module PFActive
# 2023-10-09 18:13:46,434 [   fytok]     INFO:
# ###############################################################################
# Load module Magnetics  version=None
# Magnetic diagnostics for equilibrium identification and plasma shape control.
#
# ###############################################################################
#
# 2023-10-09 18:13:46,480 [   fytok]     INFO: Load module ECLaunchers
# ...

# %%
tok_east= Tokamak(
        f"east+mdsplus:///home/salmon/workspace/fytok_data/mdsplus/~t/?enable=efit_east",  shot=70754,
    )

tok_east.refresh(time=5.0)

   
fig3=sp_view.display(tok_east, title=tok_east.short_description,styles={"interferometer": False})
# Out:
# 2023-10-09 18:12:56,277 [   fytok]     INFO:
# ###############################################################################
# Load module FyEqAnalyze  version=None
#
#     Magnetic surface analyze 磁面分析工具
# ...
#     input:
#         - vacuum_toroidal_field.b0, vacuum_toroidal_field.r0
#         - fpol, Diamagnetic function (F=R B_Phi)
#         - profiles_2d.psi (RZ 2D)
#
#     output：
#         - 识别 O,X point
#         - 识别 Separatrix, boundary
#         - Surface average
#
#
# ###############################################################################
#
# 2023-10-09 18:12:56,340 [    spdm]     INFO: Load module spdm.plugins.data.plugin_mdsplus
# 2023-10-09 18:12:56,344 [    spdm]    DEBUG: /home/salmon/workspace/output/../fytok/SpDB/python/spdm/plugins/data/plugin_mdsplus.py:118:get_tree: Open MDSplus Tree [efit_east] shot=70754
# ...
