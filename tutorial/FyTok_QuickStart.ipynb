# %% [markdown]
# # 快速启动

# %%
from fytok.Tokamak import Tokamak
# Out:
# 2023-11-25 17:29:00,347 [   fytok]     INFO:
# ###################################################################################################
#
#     ______      _____     _
#    / ____/_  __|_   _|__ | | __
#   / /_  / / / /  | |/ _ \| |/ /
#  / __/ / /_/ /   | | (_) |   <
# /_/    \__, /    |_|\___/|_|\_\
#       /____/
#
#  Copyright (c) 2021-present Zhi YU (Institute of Plasma Physics Chinese Academy of Sciences)
#
#  url: https://gitee.com/openfusion/fytok_tutorial
#       https://github.com/fusion-yun/fytok_tutorial
#
#  version = alpha  (spdm=beta extension=0.2.2.dev11+g706f667, imas_version=v3_38_1_dirty)
#
#  Run by salmon at 2023-11-25T17:29:00.347130.
#  Job ID: fytok_salmon_surface_16545
#
# ###################################################################################################

# %%
tok = Tokamak(
    "file+geqdsk://./data/g900003.00230_ITER_15MA_eqdsk16HR.txt",
    device="ITER",
    shot=900003,
    time=0.0,
)
# Out:
# 2023-11-25 17:29:00,467 [   fytok]    DEBUG: /home/salmon/workspace/fytok/SpDM/python/spdm/utils/sp_export.py:66:sp_load_module: Load module spdm.plugins.data.plugin_xml
# 2023-11-25 17:29:00,472 [   fytok]    DEBUG: /home/salmon/workspace/fytok/SpDM/python/spdm/utils/sp_export.py:66:sp_load_module: Load module spdm.plugins.data.plugin_geqdsk
# 2023-11-25 17:29:00,845 [   fytok]    DEBUG: /home/salmon/workspace/fytok/SpDM/python/spdm/utils/sp_export.py:66:sp_load_module: Load module fytok.plugins.equilibrium.fy_eq
# 2023-11-25 17:29:00,851 [   fytok]    DEBUG: /home/salmon/workspace/fytok/python/fytok/modules/Utilities.py:116:execute: Execute fytok.plugins.equilibrium.fy_eq-0.0.1 [Zhi YU@ASIPP]

# %%
print(tok.brief_summary)
# Out:
# 2023-11-25 17:29:00,890 [   fytok]    DEBUG: /home/salmon/workspace/fytok/SpDM/python/spdm/utils/sp_export.py:66:sp_load_module: Load module fytok.plugins.transport_solver_numerics.fy_trans
# Tokamak simulation :
# ---------------------------------------------------------------------------------------------------
#                                                 Brief Summary
# ---------------------------------------------------------------------------------------------------
# Dataset Description:
#
#     Device: ITER, Shot: 900003, Run: 0,
#     Run by Salmon on Surface at 2023-11-25T17:29:00.884440, base on ontology "modified imas/3"
#
# ---------------------------------------------------------------------------------------------------
# Modules:
#     transport_solver        : fy_trans-0.0.1 [fytok]
#     equilibrium             : fy_eq-0.0.1 [Zhi YU@ASIPP]
#
#     core_profiles           : N/A
#     core_transport          :
#     core_sources            :
# ---------------------------------------------------------------------------------------------------

# %%
tok
# Out:
# 2023-11-25 17:29:01,271 [   fytok]    DEBUG: /home/salmon/workspace/fytok/SpDM/python/spdm/utils/sp_export.py:66:sp_load_module: Load module spdm.mesh.mesh_rectangular
# 2023-11-25 17:29:01,497 [   fytok]    DEBUG: /home/salmon/workspace/fytok/SpDM/python/spdm/utils/sp_export.py:66:sp_load_module: Load module spdm.view.view_matplotlib

# %%
tok.equilibrium

# %%
eq_profiles_1d = tok.equilibrium.time_slice.current.profiles_1d

profs = sp_view.plot(
    [
        ((eq_profiles_1d.dvolume_dpsi, {"label": r"$\frac{dV}{d\psi}$"}), {"y_label": r"$[Wb]$"}),
        (eq_profiles_1d.dpsi_drho_tor, {"label": r"$\frac{d\psi}{d\rho_{tor}}$"}),
        (
            [
                # (bs_eq_fpol,  {"label": "astra", **bs_line_style}),
                (eq_profiles_1d.f, {"label": r"fytok"}),
            ],
            {"y_label": r"$F_{pol} [Wb\cdot m]$"},
        ),
        (
            [
                # (function_like(profiles["q"].values, bs_psi), {"label": r"astra", **bs_line_style}),
                (eq_profiles_1d.q, {"label": r"$fytok$"}),
            ],
            {"y_label": r"$q [-]$"},
        ),
        (
            [
                # (function_like(profiles["rho"].values, bs_psi), {"label": r"astra", **bs_line_style}),
                (eq_profiles_1d.rho_tor, {"label": r"$\rho$"}),
            ],
            {
                "y_label": r"$\rho_{tor}[m]$",
            },
        ),
        (
            [
                # (function_like(profiles["x"].values, bs_psi), {
                #     "label": r"$\frac{\rho_{tor}}{\rho_{tor,bdry}}$ astra", **bs_line_style}),
                (eq_profiles_1d.rho_tor_norm, {"label": r"$\bar{\rho}$"}),
            ],
            {
                "y_label": r"[-]",
            },
        ),
        (
            [
                # (function_like(4*(scipy.constants.pi**2) * R0 * profiles["rho"].values, bs_psi),
                #  {"label": r"$4\pi^2 R_0 \rho$", **bs_line_style}),
                (
                    eq_profiles_1d.dvolume_drho_tor,
                    {
                        "label": r"$dV/d\rho_{tor}$",
                    },
                ),
            ],
            {"y_label": r"$4\pi ^ 2 R_0 \rho[m ^ 2]$"},
        ),
    ],
    x_axis=tok.equilibrium.time_slice.current.profiles_1d.psi,
    # x_value=tok.equilibrium.time_slice.current.profiles_1d.psi_norm,
    x_label=r"$\bar{\psi}[-]$",
    title=r"$\psi$ dependent profiles",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> eq_profiles_1d = tok.equilibrium.time_slice.current.profiles_1d
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> profs = sp_view.plot(
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     [
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>         ((eq_profiles_1d.dvolume_dpsi, {"label": r"$\frac{dV}{d\psi}$"}), {"y_label": r"$[Wb]$"}),
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>         (eq_profiles_1d.dpsi_drho_tor, {"label": r"$\frac{d\psi}{d\rho_{tor}}$"}),
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>         (
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>             [
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>                 # (bs_eq_fpol,  {"label": "astra", **bs_line_style}),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>                 (eq_profiles_1d.f, {"label": r"fytok"}),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>             ],
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>             {"y_label": r"$F_{pol} [Wb\cdot m]$"},
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>         ),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>         (
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>             [
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a>                 # (function_like(profiles["q"].values, bs_psi), {"label": r"astra", **bs_line_style}),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>                 (eq_profiles_1d.q, {"label": r"$fytok$"}),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>             ],
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>             {"y_label": r"$q [-]$"},
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>         ),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>         (
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>             [
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>                 # (function_like(profiles["rho"].values, bs_psi), {"label": r"astra", **bs_line_style}),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>                 (eq_profiles_1d.rho_tor, {"label": r"$\rho$"}),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>             ],
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a>             {
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>                 "y_label": r"$\rho_{tor}[m]$",
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a>             },
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a>         ),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a>         (
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a>             [
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a>                 # (function_like(profiles["x"].values, bs_psi), {
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a>                 #     "label": r"$\frac{\rho_{tor}}{\rho_{tor,bdry}}$ astra", **bs_line_style}),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a>                 (eq_profiles_1d.rho_tor_norm, {"label": r"$\bar{\rho}$"}),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a>             ],
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a>             {
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=36'>37</a>                 "y_label": r"[-]",
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a>             },
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a>         ),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a>         (
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=40'>41</a>             [
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a>                 # (function_like(4*(scipy.constants.pi**2) * R0 * profiles["rho"].values, bs_psi),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a>                 #  {"label": r"$4\pi^2 R_0 \rho$", **bs_line_style}),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=43'>44</a>                 (
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=44'>45</a>                     eq_profiles_1d.dvolume_drho_tor,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=45'>46</a>                     {
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a>                         "label": r"$dV/d\rho_{tor}$",
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=47'>48</a>                     },
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=48'>49</a>                 ),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=49'>50</a>             ],
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=50'>51</a>             {"y_label": r"$4\pi ^ 2 R_0 \rho[m ^ 2]$"},
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=51'>52</a>         ),
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=52'>53</a>     ],
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=53'>54</a>     x_axis=tok.equilibrium.time_slice.current.profiles_1d.psi,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=54'>55</a>     # x_value=tok.equilibrium.time_slice.current.profiles_1d.psi_norm,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=55'>56</a>     x_label=r"$\bar{\psi}[-]$",
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=56'>57</a>     title=r"$\psi$ dependent profiles",
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/salmon/workspace/fytok_tutorial/tutorial/FyTok_QuickStart.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=57'>58</a> )
#
# NameError: name 'sp_view' is not defined

# %%
surfs = sp_view.plot(
    [
        (eq_profiles_1d.gm1, {"label": r"$gm1=\left<\frac{1}{R^2}\right>$"}),
        (eq_profiles_1d.gm2, {"label": r"$gm2=\left<\frac{\left|\nabla \rho\right|^2}{R^2}\right>$"}),
        (eq_profiles_1d.gm3, {"label": r"$gm3=\left<\left|\nabla \rho\right|^2\right>$"}),
        (eq_profiles_1d.gm4, {"label": r"$gm4=\left<1/B^2\right>$"}),
        (eq_profiles_1d.gm5, {"label": r"$gm5=\left<B^2\right>$"}),
        (eq_profiles_1d.gm6, {"label": r"$gm6=\left<\nabla \rho_{tor}^2/ B^2 \right>$"}),
        (eq_profiles_1d.gm7, {"label": r"$gm7=\left<\left|\nabla \rho\right|\right>$"}),
        (eq_profiles_1d.gm8, {"label": r"$gm8=\left<R\right>$"}),
    ],
    x_axis=tok.equilibrium.time_slice.current.profiles_1d.psi.__array__()[1:],
    # x_value=tok.equilibrium.time_slice.current.profiles_1d.psi_norm[1:],
    x_label=r"$\bar{\psi}[-]$",
    title=r"Surface averaged quantities",
)
