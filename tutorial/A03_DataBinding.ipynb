# %% [markdown]
# # SpDB（数据集成） Manual

# %%
import fytok

# %%
from fytok.modules.Equilibrium import Equilibrium

eq=Equilibrium("file+geqdsk:///home/salmon/workspace/fytok_tutorial/tutorial/data/g900003.00230_ITER_15MA_eqdsk16HR.txt#equilibrium")
# Out:
# 2023-11-19 15:17:43,643 [   fytok]     INFO:
# #######################################################################################################################
#     ______      _____     _
#    / ____/_  __|_   _|__ | | __
#   / /_  / / / /  | |/ _ \| |/ /
#  / __/ / /_/ /   | | (_) |   <
# /_/    \__, /    |_|\___/|_|\_\
#       /____/
#
#  Copyright (c) 2021-present Zhi YU (Institute of Plasma Physics Chinese Academy of Sciences)
#
#  url: https://gitee.com/openfusion/fytok_tutorial
#       https://github.com/fusion-yun/fytok_tutorial
#
#  version = develop ( imas_version=v3_38_1_dirty )
#
#  Run by jupytertest at 2023-11-19T15:17:43.643464.
#  Job ID: fytok_jupytertest_service108_195089
#
# #######################################################################################################################
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /scratch/jupytertest/workspace_fytok/fytok_tutorial/tutorial/A03_DataBinding.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bservice108-jupytertest/scratch/jupytertest/workspace_fytok/fytok_tutorial/tutorial/A03_DataBinding.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from fytok.modules.Equilibrium import Equilibrium
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bservice108-jupytertest/scratch/jupytertest/workspace_fytok/fytok_tutorial/tutorial/A03_DataBinding.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> eq=Equilibrium("file+geqdsk:///home/salmon/workspace/fytok_tutorial/tutorial/data/g900003.00230_ITER_15MA_eqdsk16HR.txt#equilibrium")
#
# File /gpfs/fuyun/projects/fuyun/fytok/python/fytok/modules/Utilities.py:98, in Module.__init__(self, *args, **kwargs)
#      96 def __init__(self, *args, **kwargs):
#      97     cache, entry, parent, kwargs = self.__class__._parser_args(*args, **kwargs)
# ---> 98     super().__init__(cache, _entry=entry, _parent=parent, **kwargs)
#
# File /gpfs/fuyun/projects/fuyun/spdm/python/spdm/data/Actor.py:29, in Actor.__init__(self, *args, **kwargs)
#      28 def __init__(self, *args, **kwargs) -> None:
# ---> 29     Pluggable.__init__(self, *args, **kwargs)
#      30     SpTree.__init__(self, *args, **kwargs)
#      31     self._inputs = {}
#
# File /gpfs/fuyun/projects/fuyun/spdm/python/spdm/utils/plugin.py:99, in Pluggable.__init__(self, *args, **kwargs)
#      97 def __init__(self, *args, **kwargs) -> None:
#      98     if self.__class__ is Pluggable or "_plugin_prefix" in vars(self.__class__):
# ---> 99         self.__class__.__dispatch_init__(None, self, *args, **kwargs)
#     100         return
#
# File /gpfs/fuyun/projects/fuyun/spdm/python/spdm/utils/plugin.py:80, in Pluggable.__dispatch_init__(cls, sub_list, self, *args, **kwargs)
#      77     cls_name = cls._get_plugin_fullname(sub_cls)
#      79     if cls_name not in cls._plugin_registry:
# ---> 80         sp_load_module(cls_name)
#      82     n_cls = cls._plugin_registry.get(cls_name, None)
#      84 elif inspect.isclass(sub_cls):
#
# File /gpfs/fuyun/projects/fuyun/spdm/python/spdm/utils/sp_export.py:61, in sp_load_module(mod_name)
#      57     return None
#      59 module = importlib.util.module_from_spec(spec)
# ---> 61 spec.loader.exec_module(module)
#      63 sys.modules[spec.name] = module
#      65 if SP_DEBUG:
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File /gpfs/fuyun/projects/fuyun/fytok/python/fytok/plugins/equilibrium/fy_eq.py:7
#       5 from dataclasses import dataclass
#       6 import numpy as np
# ----> 7 import numba
#       8 import scipy.constants
#      11 from spdm.data.Expression import Expression, Variable
#
# ModuleNotFoundError: No module named 'numba'

# %%
eq.time_slice[0].profiles_2d.psi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scratch/jupytertest/workspace_fytok/fytok_tutorial/tutorial/A03_DataBinding.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bservice108-jupytertest/scratch/jupytertest/workspace_fytok/fytok_tutorial/tutorial/A03_DataBinding.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> eq.time_slice[0].profiles_2d.psi
#
# NameError: name 'eq' is not defined

# %%
eq.time_slice[0].profiles_1d.q

# %%
eq.time_slice[0].profiles_1d.gm1
