# %%
from fytok.modules.Equilibrium import Equilibrium
from spdm.view import View as sp_view
from spdm.data.Entry import open_entry
# Out:
# 2023-10-02 14:50:31,625 [   fytok]     INFO:
# #######################################################################################################################
#
#     ______      _____     _
#    / ____/_  __|_   _|__ | | __
#   / /_  / / / /  | |/ _ \| |/ /
#  / __/ / /_/ /   | | (_) |   <
# /_/    \__, /    |_|\___/|_|\_\
#       /____/
# Copyright (c) 2021-present Zhi YU (Institute of Plasma Physics Chinese Academy of Sciences)
# URL         : https://gitee.com/openfusion/fytok_tutorial
#
# version = 0.0.0
# #######################################################################################################################
#
# 2023-10-02 14:50:31,647 [   fytok]     INFO: Mapping path [PosixPath('/home/salmon/workspace/fytok/python/fytok/_mapping')]

# %%
eq=Equilibrium("file+geqdsk:///home/salmon/workspace/fytok_tutorial/tutorial/data/g900003.00230_ITER_15MA_eqdsk16HR.txt#equilibrium")
# Out:
# 2023-10-02 14:50:32,047 [    spdm]     INFO: Load module fytok.plugins.equilibrium.eq_analyze
# 2023-10-02 14:50:32,052 [    spdm]     INFO: Load module spdm.plugins.data.plugin_geqdsk
# 2023-10-02 14:50:32,053 [    spdm]    DEBUG: /home/salmon/workspace/fytok_tutorial/../fytok/python/spdm/plugins/data/plugin_geqdsk.py:437:__init__: Open File mode=Mode.read  URITuple(protocol='file+geqdsk', authority='', path='/home/salmon/workspace/fytok_tutorial/tutorial/data/g900003.00230_ITER_15MA_eqdsk16HR.txt', query={'uid': '', 'shot': '', 'run': None}, fragment='')
# 2023-10-02 14:50:32,143 [   fytok]     INFO: Load module eq_analyze

# %%
eq.time_slice[0].profiles_2d[0].psi
# Out:
# 2023-10-02 14:50:32,189 [    spdm]     INFO: Load module spdm.view.view_matplotlib
# 2023-10-02 14:50:32,235 [    spdm]     INFO: Load module spdm.mesh.mesh_rectangular
# 2023-10-02 14:50:32,440 [    spdm]     INFO: Load module spdm.view.view_latex

# %%
fig = sp_view.plot(eq.time_slice[0].profiles_1d.q)

# %%
entry = open_entry(
    "file+geqdsk:///home/salmon/workspace/fytok_tutorial/tutorial/data/g900003.00230_ITER_15MA_eqdsk16HR.txt")
# Out:
# 2023-10-02 14:50:33,656 [    spdm]    DEBUG: /home/salmon/workspace/fytok_tutorial/../fytok/python/spdm/plugins/data/plugin_geqdsk.py:437:__init__: Open File mode=Mode.read  URITuple(protocol='file+geqdsk', authority='', path='/home/salmon/workspace/fytok_tutorial/tutorial/data/g900003.00230_ITER_15MA_eqdsk16HR.txt', query={'uid': '', 'shot': '', 'run': None}, fragment='')
